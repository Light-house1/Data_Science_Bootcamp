# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data_set = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv')

data_set.head(10)
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       1384          78.1            12.3       25627          69678
# 1       3719          43.9             9.4       13326          43292
# 2       3553          37.4            10.7        9724          33731
# 3       3916          29.9             8.8        6402          24167
# 4       2480          31.5            10.5        8502          16751
# 5       2815          23.1             6.7        7340          16941
# 6       8360          46.3             8.2        4047          14347
# 7       6794          60.1             6.3        4562          14333
# 8       3049          19.5            12.1        4005          21149
# 9       4647          31.5             9.2        3916          12815
#
#    graduates  work_force  income  region  crime_rate
# 0       50.1      4083.9   72100       1       75.55
# 1       53.9      3305.9   54542       2       56.03
# ...

# %%
data_set.crime_rate.head()
# Out:
# 0    75.55
# 1    56.03
# 2    41.32
# 3    67.38
# 4    80.19
# Name: crime_rate, dtype: float64

# %% [markdown]
# What is Scatter Plot?
#
#     * A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for different numeric variables.
#     * The position of each dot on the horizontal and vertical axis indicates values for an individual data point.
#     * Scatter plots are used to observe relationships between variables.

# %% [markdown]
# Applications of Scatter Plot
#
#     A scatter plot can be useful for identifying other patterns in data.
#     We can divide data points into groups based on how closely sets of points cluster together.
#     Scatter plots can also show if there are any unexpected gaps in the data and if there are any outlier points. (Look at the 2 points away from rest of the data in the scatter plot. Those are outliers.)
#     This can be useful if we want to segment the data into different parts, like categorising users into different groups.

# %%
plt.scatter(data_set.crime_rate, data_set.percent_senior)
plt.show()

# %% [markdown]
# Line Plot
#
# A line chart is used to represent data over a continuous time span. It is generally used to show trend of a variable over time. Data values are plotted as points that are connected using line segments.

# %% [markdown]
# Creating a Line Plot (with 2 arguments)
#
#     In Matplotlib we can create a line chart by calling the plot method.
#     plot() is a versatile command, and can take an arbitrary number of arguments.

# %%
plt.plot(data_set.work_force, data_set.income) #2 args: X and Y points
plt.show()

# %% [markdown]
# Creating a Line Plot(with a single argument)
#
#     We can make a graph with a simple list

# %%
plt.plot([1,2,3,4,]) #1 arg
plt.show()

# %% [markdown]
# Histogram
#
# A histogram is a graphical display of data using bars(rectangles) of different heights.
# Parts of a Histogram
#
#     The title: The title describes the information included in the histogram.
#     X-axis: The X-axis are intervals that show the scale of values which the measurements fall under. These intervals are also called bins.
#     Y-axis: The Y-axis shows the number of times that the values occurred(frequency) for each interval on the X-axis.
#     The bars: The height of the bar shows the number of times the values occurred within the interval, while the width of the bar shows the covered interval.

# %%
plt.hist(data_set.percent_senior) #it takes a single array or a sequence of arrays
plt.show()

# %% [markdown]
# Bar Plot
#
# Bar charts are one of the most common graphs used to show data associated with categorical variables.

# %% [markdown]
# Creating a Vertical Bar Plot
#
# Pyplot provides a bar() method to make bar graphs that take the following arguments: categorical variables, their values, and color (if you want to specify any).

# %%
plt.bar(data_set.region, data_set.crime_rate)
plt.show()

# %% [markdown]
# Creating a Horizontal Bar Plot
#
# Making a horizontal bar chart is also really simple using the plt.barh() method.

# %%
plt.barh(data_set.region, data_set.crime_rate)
plt.show()

# %% [markdown]
# Pie Chart
# What is Pie Chart?
#
#     A pie chart (or a circle chart) is a circular statistical graphic, which is divided into slices(wedges) to illustrate numerical proportion.
#
# Parameters of a pie chart
#
#     x: The wedge sizes.
#     labels: A sequence of strings providing the labels for each wedge.
#     Colors: A sequence of colors through which the pie chart will cycle. If None, will use the colors in the currently active cycle.
#     Autopct: string, used to label the wedges with their numeric value. The label will be placed inside the wedge. The format string will be fmt%pct. The value %1.1f%% is the Python number format .1f% (which includes the percentage symbol %), rounding off the number to one decimal place.

# %%
from turtle import title


firms = ['firm A', 'firm B', 'firm C', 'firm D', 'firm E']
market_share = [20,25,15,10,20]

Explode = [0,0.1,0,0,0]

plt.pie(market_share,shadow=True, explode=Explode, labels=firms, autopct='%1.2f%%')
plt.legend(title='firms')
plt.show()
plt.savefig("piechart.png", bbox_inches = 'tight', pad_inches = 2)

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23, 17, 35, 29, 12]
plt.pie(students, labels=langs, autopct='%1.1f%%')
plt.axis('equal') #this makes the circle perfect
plt.show()

# %% [markdown]
# Combining the 2 plots into 1

# %%
from turtle import color

plt.title('combined plots')
plt.plot(data_set.work_force, data_set.income, color = 'r')
plt.plot(data_set.physicians, data_set.income)
plt.xlabel('work_force, physicians')
plt.ylabel('income')
plt.show()

# %% [markdown]
# Changing Line Styles

# %%
# plt.plot(data_set.work_force, data_set.income, linestyle = '--')#dashed
# plt.plot(data_set.work_force, data_set.income, '-')#solid
# plt.plot(data_set.work_force, data_set.income, '-.')#dashdot
plt.plot(data_set.work_force, data_set.income, ':')#dotted

# %% [markdown]
# Adding Markers

# %%
# plt.plot(data_set.work_force, data_set.income, marker = 'o')#circular markers
# plt.plot(data_set.work_force, data_set.income, 'x')#crosses
plt.plot(data_set.work_force, data_set.income, '^')# triangles
plt.show()

# %% [markdown]
# Combining the 3 formatting options

# %%
plt.plot(data_set.work_force, data_set.income, '--ro')

# %% [markdown]
# Multiple Plots in 1 Figure

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2,1,1) #row,column,index
plt.plot(data_set.work_force, data_set.income, 'ro')
# plt.title('work_force vs income')

plt.subplot(2, 1, 2)
plt.plot(data_set.physicians, data_set.income)
# plt.title('physicians vs income')

plt.suptitle('Sub plots') #general title
plt.show()

# %% [markdown]
# Changing the size of the plots

# %%
plt.figure(figsize=(12, 5))
plt.plot(data_set.work_force, data_set.income, 'ro')
plt.show()

# %%
fig, ax = plt.subplots(2)
ax[0].plot(data_set.work_force, data_set.income, 'go')
ax[1].plot(data_set.work_force, data_set.income, 'ro')
plt.show()

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (6,6)) #creating a grid of 2 rows, 2 columns and 6x6 figsize

ax[0,0].plot(data_set.work_force, data_set.income, 'go')
ax[0,1].plot(data_set.work_force, data_set.income, 'ro')
ax[1,0].plot(data_set.work_force, data_set.income, 'bo')
ax[1, 1].plot(data_set.work_force, data_set.income, 'ro')
plt.show()

# %%
data_set.head()
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       1384          78.1            12.3       25627          69678
# 1       3719          43.9             9.4       13326          43292
# 2       3553          37.4            10.7        9724          33731
# 3       3916          29.9             8.8        6402          24167
# 4       2480          31.5            10.5        8502          16751
#
#    graduates  work_force  income  region  crime_rate
# 0       50.1      4083.9   72100       1       75.55
# 1       53.9      3305.9   54542       2       56.03
# 2       50.6      2066.3   33216       1       41.32
# 3       52.2      1966.7   32906       2       67.38
# 4       66.1      1514.5   26573       4       80.19

# %%
# checks number of datatypes
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   land_area       99 non-null     int64
#  1   percent_city    99 non-null     float64
#  2   percent_senior  99 non-null     float64
#  3   physicians      99 non-null     int64
#  4   hospital_beds   99 non-null     int64
#  5   graduates       99 non-null     float64
#  6   work_force      99 non-null     float64
#  7   income          99 non-null     int64
#  8   region          99 non-null     int64
#  9   crime_rate      99 non-null     float64
# dtypes: float64(5), int64(5)
# memory usage: 7.9 KB

# %%
#Which of the following is the first five land area of the metropolitan area data which are located in region 4?
data_set[data_set['region']==4]['land_area'].head()
# Out:
# 4      2480
# 13      782
# 14     4226
# 18    27293
# 20     9155
# Name: land_area, dtype: int64

# %%
data_set[(data_set['region']==4) & (data_set['crime_rate'] == 55.64)]
# Out:
# Empty DataFrame
# Columns: [land_area, percent_city, percent_senior, physicians, hospital_beds, graduates, work_force, income, region, crime_rate]
# Index: []

# %%
data_set[(data_set.region == 4) & (data_set.land_area == 2480)]
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 4       2480          31.5            10.5        8502          16751
#
#    graduates  work_force  income  region  crime_rate
# 4       66.1      1514.5   26573       4       80.19

# %%
data_set.land_area.mean()
# Out:
# 2615.7272727272725

# %%
data_set.crime_rate.max()
data_set.crime_rate.mean()
# Out:
# 55.6430303030303

# %%
data_set.income.min()
# Out:
# 769

# %%
data_set.region.value_counts()
# Out:
# 3    36
# 2    25
# 1    21
# 4    17
# Name: region, dtype: int64

# %%
data_set.hospital_beds.value_counts(dropna= False)
# Out:
# 69678    1
# 1837     1
# 5430     1
# 2630     1
# 1455     1
#         ..
# 3459     1
# 4342     1
# 4730     1
# 5512     1
# 1296     1
# Name: hospital_beds, Length: 99, dtype: int64

# %%
plt.plot(data_set.land_area,data_set.crime_rate)
plt.show()

# %%
plt.scatter(data_set.hospital_beds, data_set.physicians)
plt.show()

# %%
plt.bar([1,2,3,4], data_set.region.value_counts())
plt.show()

# %%
plt.hist( data_set.income)
plt.show()
